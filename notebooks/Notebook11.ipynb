# %%
import pandas as pd

# %%
df = pd.read_csv("reports/report_val_z.csv")
df
# Out:
#         Unnamed: 0                        DB  \
# 0                0  .data/dbs/a0x8o/kafka.db
# 1                1  .data/dbs/a0x8o/kafka.db
# 2                2  .data/dbs/a0x8o/kafka.db
# 3                3  .data/dbs/a0x8o/kafka.db
# 4                4  .data/dbs/a0x8o/kafka.db
# ...            ...                       ...
# 116709      116709          .data/depends.db
# 116710      116710          .data/depends.db
# 116711      116711          .data/depends.db
# 116712      116712          .data/depends.db
# 116713      116713          .data/depends.db
#
#                                                  Filename  \
# 0       clients/src/main/java/org/apache/kafka/clients...
# 1       clients/src/main/java/org/apache/kafka/clients...
# 2       clients/src/main/java/org/apache/kafka/clients...
# 3       clients/src/main/java/org/apache/kafka/clients...
# 4       clients/src/main/java/org/apache/kafka/clients...
# ...                                                   ...
# ...

# %%
deicide_df = pd.read_csv("reports/deicide_results.csv")

# %%
df = df[df["Filename"].isin(set(deicide_df["filename"]))]
df
# Out:
#        Unnamed: 0                         DB  \
# 2880         2880   .data/dbs/a0x8o/kafka.db
# 2883         2883   .data/dbs/a0x8o/kafka.db
# 37188       37188   .data/dbs/apache/hudi.db
# 37246       37246   .data/dbs/apache/hudi.db
# 37247       37247   .data/dbs/apache/hudi.db
# 37277       37277   .data/dbs/apache/hudi.db
# 37311       37311   .data/dbs/apache/hudi.db
# 37453       37453   .data/dbs/apache/hudi.db
# 37456       37456   .data/dbs/apache/hudi.db
# 58150       58150  .data/dbs/apache/kafka.db
# 58153       58153  .data/dbs/apache/kafka.db
# 63057       63057   .data/dbs/apache/nifi.db
# 66506       66506   .data/dbs/apache/nifi.db
# 66510       66510   .data/dbs/apache/nifi.db
# 66517       66517   .data/dbs/apache/nifi.db
# 70628       70628  .data/dbs/apache/pinot.db
# 70652       70652  .data/dbs/apache/pinot.db
# 70678       70678  .data/dbs/apache/pinot.db
# 70686       70686  .data/dbs/apache/pinot.db
# 70740       70740  .data/dbs/apache/pinot.db
# ...

# %%
df.to_csv("reports/deicide_scores.csv")

# %%
len(df)
# Out:
# 27
